# %%
import pandas as pd

# %%
col_orig=pd.read_excel('/Users/jaqueline/Documents/demandas/dsu_col_25.xlsx',header=1)
revision=pd.read_excel('/Users/jaqueline/Documents/demandas/revision.xlsx',header=1)

# %%
col_orig
# Out:
#       cvegeo    id                   nomgeo  PROTECCIÓN CIVIL  VIALIDADES  \
# 0     200001     1         27 De Septiembre                 2           0
# 1     200003     3                El Papago                 4           1
# 2     200004     4          Primera Seccion                10           5
# 3     200005     5          Segunda Seccion                25           2
# 4     200006     6              La Jabonera                 8           0
# ...      ...   ...                      ...               ...         ...
# 1609  202346  2346  Villa Paraiso La Gloria                 0           0
# 1610  202347  2347      Lomas De San Martin                 0           1
# 1611  202349  2349     Ex Ejido Chapultepec                 1           3
# 1612  202352  2352     Ex Ejido Chapultepec                 3           4
# 1613  202353  2353               Montebello                 1           0
#
#       AGUA  ALUMBRADO Y ELECTRICIDAD  BASURA  ESPACIOS PÚBLICOS  Total
# ...
